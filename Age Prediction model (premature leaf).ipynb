# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
da = []

da.append(pd.read_csv('/home/siddhant/Downloads/Dataset 1.csv'))
da.append(pd.read_csv('/home/siddhant/Downloads/Dataset 2.csv'))
da.append(pd.read_csv('/home/siddhant/Downloads/Dataset 3.csv'))
da.append(pd.read_csv('/home/siddhant/Downloads/Dataset 4.csv'))
da.append(pd.read_csv('/home/siddhant/Downloads/Dataset 5.csv'))
da.append(pd.read_csv('/home/siddhant/Downloads/Dataset 6.csv'))
da.append(pd.read_csv('/home/siddhant/Downloads/Dataset 7.csv'))
da.append(pd.read_csv('/home/siddhant/Downloads/Dataset 8.csv'))
da.append(pd.read_csv('/home/siddhant/Downloads/Dataset 9.csv'))

# %%
da[0].plot('Length', 'Age',style = '.')

# %%
da[3].plot('Length', 'Age',style = '.')

# %%
da[6].plot('Length', 'Age',style = '.')

# %%
da[8].plot('Length', 'Age',style = '.')

# %%
from sklearn.preprocessing import PolynomialFeatures 
from sklearn.linear_model import LinearRegression

# %%
X = []
y = []
for i in range(0, 9):
    y.append(da[i].iloc[:, 0:1].values)
    X.append(da[i].iloc[:, 1:2].values)

# %%
num = int(input("Enter the succession of the leaf from the bottom"))
num = num - 1
# Out:
# Enter the succession of the leaf from the bottom 2

# %%
poly = PolynomialFeatures(degree = 3) 
X_poly = poly.fit_transform(X[num]) 
  
poly.fit(X_poly, y[num]) 
lin2 = LinearRegression() 
lin2.fit(X_poly, y[num])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
plt.scatter(X[num], y[num], color = 'blue') 
  
plt.plot(X[num], lin2.predict(poly.fit_transform(X[num])), color = 'red') 
plt.title('Polynomial Regression') 
plt.xlabel('Length') 
plt.ylabel('Age') 
  
plt.show()

# %%
lin2.predict(poly.fit_transform(40))
# Out:
# array([[14.63509043]])
